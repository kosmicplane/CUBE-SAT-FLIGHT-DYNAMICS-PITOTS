# %%
import pandas as pd
import numpy as np

# Nombres de columnas
column_names = [
    "time", "height",
    "bme_temp", "bme_press", "bme_hum",
    "bmp_temp", "bmp_press", "voc_raw",
    "accel_x", "accel_y", "accel_z",
    "lin_accel_x", "lin_accel_y", "lin_accel_z",
    "gyro_x", "gyro_y", "gyro_z",
    "mag_x", "mag_y", "mag_z",
    "euler_x", "euler_y", "euler_z",
    "quat_w", "quat_x", "quat_y", "quat_z",
    "year", "month", "day", "hour", "minute", "second",
    "lon", "lat", "alt", "velN", "velE", "velD",
    "pump_feedback", "valven_feedback", "valve1_feedback", "valve2_feedback", "press_1", "temp_1",
    "press_2", "temp_2", "press_3", "temp_3", "press_4", "temp_4",
]

# Generar datos simulados
data_multiple = [np.random.random(len(column_names)) * 100 for _ in range(200)]
df = pd.DataFrame(data_multiple, columns=column_names)

# Guardar como CSV
df.to_csv("datos_vuelo_200_filas.csv", index=False)
